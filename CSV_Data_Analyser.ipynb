# %% [markdown]
# <a href="https://colab.research.google.com/github/aakankshalahane/Machine-Learning-Projects/blob/main/CSV_Data_Analyser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
print("📘 Project 1: CSV Data Analyzer")
data = pd.DataFrame({
    'Name': ['Asha', 'Kamal', 'Priya', 'Ravi'],
    'Age': [22, 24, 21, 23],
    'Score': [85, 90, 78, 88]
})
print(data)
print("\nSummary:\n", data.describe())
print("\nMissing Values:\n", data.isnull().sum())
# Out:
# 📘 Project 1: CSV Data Analyzer
#     Name  Age  Score
# 0   Asha   22     85
# 1  Kamal   24     90
# 2  Priya   21     78
# 3   Ravi   23     88
#
# Summary:
#               Age      Score
# count   4.000000   4.000000
# mean   22.500000  85.250000
# std     1.290994   5.251984
# min    21.000000  78.000000
# 25%    21.750000  83.250000
# 50%    22.500000  86.500000
# 75%    23.250000  88.500000
# max    24.000000  90.000000
#
# Missing Values:
#  Name     0
# Age      0
# Score    0
# dtype: int64
